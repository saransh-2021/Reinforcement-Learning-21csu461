# %% [markdown]
# <a href="https://colab.research.google.com/github/saransh-2021/Reinforcement-Learning-21csu461/blob/main/Correlation_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import plotly.express as px

# %%
np.random.seed(42)

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)
x

# %%
# Positive correlation with some noise
y = x + np.random.normal(0, 10, 1000)
y

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81014352],
#        [0.81014352, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()
#positive

# %%
px.scatter(x= x, y= y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y = x - np.random.normal(0, 10, 1000)
y

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82686377],
#        [0.82686377, 1.        ]])

# %%
plt.scatter(x, y)
plt.show()
#positive

# %%
px.scatter(x= x, y= y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = np.random.randint(0, 50, 1000)

y= 100 - x + np.random.normal(0, 5, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.       , -0.9468869],
#        [-0.9468869,  1.       ]])

# %%
plt.scatter(x,y)

# %%
px.scatter(x=x,y=y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = np.random.randint(0, 50, 1000)
y = x + np.random.normal(0, 25, 1000)

z = 100 - x + np.random.normal(0,25,1000)

# %%
np.corrcoef(x,y) , np.corrcoef(x,z)
# Out:
# (array([[1.        , 0.49220683],
#         [0.49220683, 1.        ]]),
#  array([[ 1.        , -0.50722826],
#         [-0.50722826,  1.        ]]))

# %%
plt.scatter(x, y)
plt.scatter(x, z)

# %%
x = np.random.randint(0,50,1000)
y = np.random.randint(0,50,1000)

print(np.corrcoef)

plt.scatter(x, y)
# Out:
# <function corrcoef at 0x7ef6bd3d89d0>

# %%
import pandas as pd

df = pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100 - df['a'] + np.random.normal(0,10,1000)
df['d'] = np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.822072 -0.821341 -0.011092
# b  0.822072  1.000000 -0.680148 -0.046435
# c -0.821341 -0.680148  1.000000 -0.015427
# d -0.011092 -0.046435 -0.015427  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize = (6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >
